# %%
import numpy as np
import uproot
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import integrate
from scipy import signal
from scipy.fft import fftshift

# %%
ClockDDC10 = 6e8
adccperVolt = 8192
resistance_ohm = 50
sampleWidth_ns = 10
# filter parameters
A = 1.0
B = 0.5
n = 1
m = n
fWidth = 2*n + m
fmask = np.concatenate((B*np.ones(shape=n),-A*np.ones(shape=m),B*np.ones(shape=n)))

# %%
from numba import jit
#@jit#(nopython=True) # Set "nopython" mode for best performance, equivalent to @njit
def ReadDDC10_BinWave(fName, doTime=False):
    waveInfo = {}
    fp = open(fName+'.bin','rb')
    Header = np.fromfile(fp,dtype=np.uint32,count=4)
    
    waveInfo['numEvents'] = int(Header[0])
    waveInfo['numSamples'] = int(Header[1])
    waveInfo['chMap'] = np.array([1 if digit=='1' else 0 for digit in bin(Header[2])[2:]])
    waveInfo['numChan'] = waveInfo['chMap'].sum()
    byteOrderPattern = hex(int(np.fromfile(fp,dtype=np.uint32,count=1)))
    
    tmpArr = np.concatenate((np.fromfile(fp,dtype=np.int16),np.zeros(2)))
    fp.close()
    #if waveInfo['numChan']>1:
    waveArr = np.reshape(tmpArr.astype(dtype=np.float64)/adccperVolt,(waveInfo['numEvents'],waveInfo['numChan'],(waveInfo['numSamples']+6)))[...,2:-4]
    #else:
        #waveArr = np.reshape(tmpArr.astype(dtype=np.float64)/adccperVolt,(waveInfo['numEvents'],(waveInfo['numSamples']+6)))[...,2:-4]
    
    if doTime:
        with open(fName+'.log','r') as fl:
            waveInfo['liveTimes_s'] = np.loadtxt(fl,delimiter=',',skiprows=5,max_rows=waveInfo['numEvents'],usecols=(2),dtype=np.float64)/(ClockDDC10)
            waveInfo['totliveTime_s'] = np.sum(waveInfo['liveTimes_s'])
    return (waveArr,waveInfo)

# %%
waveArr,waveInfo = ReadDDC10_BinWave("/data/share/KA0206_BarrelDry_OCS_200303_350_samples_100000_events/ShapeTest10dB_OCSw5",True)
print(waveArr.shape)
waveInfo
# Out:
# (100000, 3, 350)
# {'numEvents': 100000,
#  'numSamples': 350,
#  'chMap': array([1, 0, 1, 0, 0, 0, 0, 0, 1]),
#  'numChan': 3,
#  'liveTimes_s': array([1.54166667e-06, 2.35340000e-04, 2.62540000e-04, ...,
#         1.58756667e-04, 2.74935000e-04, 2.01465000e-04]),
#  'totliveTime_s': 17.613799091666667}

# %%
peaks = np.argmax(np.absolute(waveArr[:,0,:]),axis=1)
peakheights = np.max(np.absolute(waveArr[:,0,:]),axis=1)
#nBins = waveInfo['numSamples']
hpeaks = np.histogram(peaks,bins = waveInfo['numSamples'],range=(0,waveInfo['numSamples']))
plt.plot(hpeaks[1][:-1],hpeaks[0]/waveInfo['totliveTime_s'],marker='+')
#nBins = 1000
#hpeakh = np.histogram(peakheights,bins = nBins,range=(0,1))
#plt.plot(np.arange(0,1,1/nBins),hpeakh[0]/waveInfo['totliveTime_s'],marker='x')
plt.yscale('log')
#plt.xlim((-0.01,0.05))

# %%
hpeaktime = np.histogram2d(peaks,peakheights,bins=[int(waveInfo['numSamples']/10.0),500],range=[[0,waveInfo['numSamples']],[0,1]])
hpeaktime[2].shape
plt.pcolormesh(hpeaktime[1][:-1],hpeaktime[2][:-1],np.transpose(hpeaktime[0])/waveInfo['totliveTime_s'],norm=mpl.colors.LogNorm())
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=20)
plt.xlabel("peak time (samples)")
plt.ylabel("peak height (mV)")

#plt.axis([0,350,0.002,0.015])
#cbar.set_clim([0,5])
# Out:
# Text(0, 0.5, 'peak height (mV)')

# %%
plt.figure()
#for i in range(5000):
    #plt.plot(filteredWave[i,:],marker='x')
    #plt.plot(waveArr[i,0,:],marker='+')
plt.plot(waveArr[500,1,:],marker='+')
plt.plot(waveArr[500,2,:],marker='x')
plt.xlim((170,350))
#plt.yscale('log')
plt.show()

# %%
#waveFFT = np.fft.rfft(waveArr)
#print(waveFFT.shape)
f,t,waveSpec = signal.spectrogram(waveArr[1,1],1/sampleWidth_ns,scaling='spectrum',nperseg=3,nfft=150)

print(waveSpec.shape)
print(f.shape)
print(t.shape)
plt.pcolormesh(t/10,1e3*f,waveSpec)
plt.ylabel('Frequency [MHz]')
plt.xlabel('Time [10ns]')
plt.xlim((210,230))
# Out:
# (76, 116)
# (76,)
# (116,)
# (210, 230)

# %%
#baseline and rms
nBaseSamps = 150
baseWave = waveArr[...,:nBaseSamps]
waveBaseline = np.sum(baseWave,axis = 2)/nBaseSamps
waveBaserms = np.sqrt(np.sum(baseWave*baseWave,axis = 2)/nBaseSamps - waveBaseline*waveBaseline)
waveArr = waveArr - waveBaseline[...,np.newaxis]

plt.figure()
for i in range(500):
    #plt.plot(filteredWave[i,:],marker='x')
    plt.plot(waveArr[i,1,:],marker='+')
plt.xlim((170,350))
plt.show()

# %%
#total event charge
waveQBase = 1e3*integrate.simps(waveArr[...,:nBaseSamps],axis=2)*sampleWidth_ns/resistance_ohm
waveQ_pC = 1e3*integrate.simps(waveArr[...,185:280],axis=2)*sampleWidth_ns/resistance_ohm
#len(waveInfo['liveTimes_s'])

#baseMask = np.absolute(waveQBase*np.reciprocal(nBaseSamps*waveBaserms.flatten()))<2

print(waveBaseline)
waveQ_pC
# Out:
# [[-0.0008667  -0.0064738   0.00318441]
#  [-0.00217611 -0.00577718  0.00328125]
#  [-0.00299723 -0.00656901  0.00325358]
#  ...
#  [-0.00104085 -0.00616374  0.00316895]
#  [-0.00159912 -0.00654867  0.00324137]
#  [-0.00319743 -0.00666097  0.00319906]]
# array([[ 561.36230469, 1975.45898438,  136.27571615],
#        [ 531.72298177, 1851.56347656,  130.68717448],
#        [ 619.58040365, 1883.14095052,  123.70410156],
#        ...,
#        [ 487.87044271, 1816.37467448,  130.34082031],
#        [ 551.18164062, 1850.84928385,  140.2828776 ],
#        [ 560.67317708, 1843.34147135,  134.95865885]])

# %%
plt.figure()
prange = [-2,2500]
nBins = 5000
spacing = (prange[1]-prange[0])/nBins
#goodWaveQ = waveQ_pC[baseMask]
#Qhist1 = np.histogram(waveQ_pC[:,1],nBins,range=prange,weights=np.ones(shape=waveQ_pC[:,0].shape)/waveInfo['totliveTime_s'])
Qhist2d = np.histogram2d(waveQ_pC[:,1],waveQ_pC[:,2],bins=nBins,range = [prange,prange])

plt.pcolormesh(Qhist2d[1][:-1],Qhist2d[2][:-1],Qhist2d[0]/waveInfo['totliveTime_s'],norm=mpl.colors.LogNorm())
#plt.plot(Qhist1[1][:-1],Qhist1[0])
plt.xlabel('Q1 [pC]')
plt.ylabel('Q2 [pC]')
#plt.xlim((-3,10))
#plt.yscale('log')
cbar = plt.colorbar()
plt.show()
print(int((1-prange[0])/spacing))
#print('Integrated Rate > 1pC = '+str(np.sum(Qhist2d[0][int((1.0-prange[0])/spacing):]))+' Hz')
# Out:
# 5

# %%
Qratio = waveQ_pC[:,1]/waveQ_pC[:,2]
Qratiohist = np.histogram(Qratio,bins=5000,range=(-2,20))
plt.plot(Qratiohist[1][:-1],Qratiohist[0])
#plt.yscale('log')
plt.xlim((10,18))
#plt.xticks(np.arange(13, 15, step=0.25))
# Out:
# (10, 18)

# %%
testEv = waveArr[1]
plt.plot(testEv[1],marker='+')
plt.plot(testEv[2],marker='x')
plt.xlim((190,250))
#plt.yscale('log')
plt.show()

# %%
def LoGkernel(size=3,sigma=1,scale=1):
    sigma2 = sigma*sigma
    kernel = np.ones(size)
    x = (np.arange(size) - (size-1)/2.0)*scale
    kernel = (x*x/sigma2 - kernel)/sigma2
    x2 = np.exp(-x*x/(2*sigma2))
    print(x)
    print(kernel)
    return kernel*x2
def mycorrelate(kernel,arr):
    np.correlate(arr,kernel,mode="full")

# %%
ksize = 3
ksigma = 1
kernel = LoGkernel(ksize,ksigma,2)
print(kernel)

# %%
filtered = np.correlate(testEv[2],kernel,mode="full")[int(ksize/2):-int(ksize/2)]
print(filtered.shape)
plt.plot(filtered,marker='x')
plt.plot(testEv[2],marker='+')
plt.xlim((200,220))
