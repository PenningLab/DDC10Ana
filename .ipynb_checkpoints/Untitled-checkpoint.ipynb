# %%
import numpy as np
import uproot
import matplotlib.pyplot as plt
from scipy import integrate
import AnaUtils as au

# %%
wdir = '/data/share/SA5446/Gain_1500V_200617_100_samples_20000_events/0'
waves = au.ReadDDC10_BinWave(wdir)
waves
# Out:
# [array([[[0.00927734, 0.00927734, 0.0090332 , ..., 0.0090332 ,
#           0.00915527, 0.00976562],
#          [0.00073242, 0.00012207, 0.00061035, ..., 0.00012207,
#           0.00048828, 0.00061035]],
#
#         [[0.00939941, 0.00878906, 0.00927734, ..., 0.00939941,
#           0.00939941, 0.00927734],
#          [0.        , 0.00012207, 0.00036621, ..., 0.00036621,
#           0.00061035, 0.00036621]],
#
#         [[0.00915527, 0.00939941, 0.00878906, ..., 0.00964355,
#           0.00927734, 0.00952148],
#          [0.00036621, 0.00012207, 0.00036621, ..., 0.00061035,
#           0.00061035, 0.        ]],
#
#         ...,
#
#         [[0.00866699, 0.0090332 , 0.00952148, ..., 0.0111084 ,
#           0.01062012, 0.01013184],
#          [0.00024414, 0.00024414, 0.        , ..., 0.00061035,
#           0.00036621, 0.00048828]],
#
#         [[0.01135254, 0.0111084 , 0.01049805, ..., 0.00964355,
#           0.01000977, 0.00964355],
#          [0.00012207, 0.00036621, 0.00012207, ..., 0.00048828,
#           0.00036621, 0.00012207]],
#
#         [[0.0090332 , 0.00915527, 0.00939941, ..., 0.0090332 ,
#           0.00878906, 0.00744629],
#          [0.00012207, 0.00036621, 0.        , ..., 0.00073242,
#           0.00073242, 0.00024414]]]),
#  {'numEvents': 20000,
#   'numSamples': 100,
#   'chMap': array([1, 0, 1]),
#   'numChan': 2,
#   'liveTimes_s': array([3.90833333e-06, 1.02346667e-04, 1.94438333e-04, ...,
#          1.67943333e-04, 2.42546667e-04, 2.78513333e-04]),
#   'totliveTime_s': 3.969244831666667}]

# %%
nbase=30
waves[0],base = au.Subtract_Baseline(waves[0],nBase=nbase)
bmask = np.absolute(integrate.simps(waves[0][:,1,:nbase]))<3*integrate.simps(np.ones(nbase))*base[1][:,1]

# %%
TrigPeaks = au.peakHist(waves,chan=0,ret=True)[1:]
wStart = TrigPeaks[0]+5
wFin = TrigPeaks[0]+30
tmask = TrigPeaks[1]>100

# %%
evmask = bmask*tmask

# %%
Qhist = au.winQHist(waves,ch=1,init=wStart.astype(int),end=wFin.astype(int),nBins=1000,evMask=evmask[...,np.newaxis])

# %%
plt.plot(Qhist['qHist'][1],Qhist['qHist'][0])
#plt.yscale('log')
#plt.xlim(-2,10)
plt.xlabel('Q [pC]')
plt.ylabel('Rate [Hz]')
# Out:
# Text(0, 0.5, 'Rate [Hz]')
