# %%
import numpy as np
import uproot
import matplotlib.pyplot as plt
from scipy import integrate
import AnaUtils as au
import Triggered as tr
import glob,os
from pylab import rcParams
rcParams['figure.figsize'] = 30, 20
rcParams['font.size'] = 24

# %%
wDir = '/data/share/KA0219/UV'
fWaves = [os.path.splitext(iF)[0] for iF in glob.glob(wDir+'/*.bin')]
fWaves.sort()
fWaves,wDir[22:].split('/')
# Out:
# (['/data/share/KA0219/UV/1780V_00.05pGdLS2_5V_700ns_200806_500_samples_30000_events',
#   '/data/share/KA0219/UV/1780V_00.1pGdLS2_5V_700ns_200806_500_samples_30000_events',
#   '/data/share/KA0219/UV/1780V_00.5pGdLS2_5V_700ns_200806_500_samples_30000_events',
#   '/data/share/KA0219/UV/1780V_00pGdLS2_5V_700ns_200807_500_samples_30000_events',
#   '/data/share/KA0219/UV/1780V_01pGdLS_5V_700ns_200806_500_samples_30000_events',
#   '/data/share/KA0219/UV/1780V_02pGdLS_5V_700ns_200806_500_samples_30000_events',
#   '/data/share/KA0219/UV/1780V_05pGdLS_5V_700ns_200806_500_samples_30000_events',
#   '/data/share/KA0219/UV/1780V_100GdLS_5V_700ns_200806_500_samples_30000_events',
#   '/data/share/KA0219/UV/1780V_Air_5V_700ns_200806_500_samples_30000_events'],
#  [''])

# %%
waveArrs = [au.ReadDDC10_BinWave(iRun) for iRun in fWaves]
for wave in waveArrs:
    if wave is None:
        waveArrs.remove(None)
waveArrs
# Out:
# [[array([[[-0.40429688, -0.40454102, -0.40454102, ..., -0.40368652,
#            -0.40319824, -0.40356445],
#           [-0.79223633, -0.79223633, -0.7923584 , ..., -0.79296875,
#            -0.79296875, -0.79272461]],
#
#          [[-0.40405273, -0.40429688, -0.40527344, ..., -0.40344238,
#            -0.40368652, -0.40405273],
#           [-0.79260254, -0.79272461, -0.7923584 , ..., -0.79260254,
#            -0.79284668, -0.79296875]],
#
#          [[-0.40466309, -0.40441895, -0.40454102, ..., -0.40393066,
#            -0.40393066, -0.40380859],
#           [-0.7923584 , -0.79223633, -0.79260254, ..., -0.79248047,
#            -0.79260254, -0.79248047]],
#
#          ...,
#
#          [[-0.40429688, -0.40393066, -0.40441895, ..., -0.40368652,
#            -0.40368652, -0.40344238],
#           [-0.79272461, -0.79260254, -0.79248047, ..., -0.79248047,
#            -0.79260254, -0.79309082]],
#
#          [[-0.40393066, -0.40405273, -0.4041748 , ..., -0.40368652,
#            -0.40356445, -0.40344238],
#           [-0.79284668, -0.79223633, -0.7923584 , ..., -0.79248047,
#            -0.79248047, -0.79260254]],
#
#          [[-0.40405273, -0.4041748 , -0.40393066, ..., -0.40356445,
#            -0.40344238, -0.40332031],
#           [-0.79248047, -0.79248047, -0.7923584 , ..., -0.79248047,
#            -0.79248047, -0.7923584 ]]]),
#   {'numEvents': 30000,
#    'numSamples': 500,
#    'chMap': array([1, 0, 1]),
#    'numChan': 2,
#    'file': '/data/share/KA0219/UV/1780V_00.05pGdLS2_5V_700ns_200806_500_samples_30000_events',
#    'liveTimes_s': array([1.54166667e-06, 1.21016333e-03, 2.37476333e-03, ...,
#           2.66638500e-03, 1.43190167e-03, 2.70218500e-03]),
#    'totliveTime_s': 69.21091097499999}],
#  [array([[[-0.40380859, -0.40405273, -0.4041748 , ..., -0.40368652,
#            -0.40368652, -0.40356445],
#           [-0.7923584 , -0.79260254, -0.7923584 , ..., -0.79272461,
#            -0.79296875, -0.79309082]],
#
#          [[-0.40429688, -0.40429688, -0.40393066, ..., -0.40368652,
#            -0.40332031, -0.40344238],
#           [-0.79284668, -0.7923584 , -0.79272461, ..., -0.79296875,
#            -0.79284668, -0.79260254]],
#
#          [[-0.40405273, -0.40429688, -0.40429688, ..., -0.40380859,
#            -0.40356445, -0.40356445],
#           [-0.79272461, -0.79260254, -0.79272461, ..., -0.79284668,
#            -0.79260254, -0.79296875]],
#
#          ...,
#
#          [[-0.4041748 , -0.40405273, -0.40380859, ..., -0.40405273,
#            -0.40380859, -0.40307617],
5V_700ns_200806_500_samples_30000_events',
#    'liveTimes_s': array([1.50833333e-06, 6.09271667e-04, 2.35342167e-03, ...,
#           2.46093500e-03, 2.24690500e-03, 1.68072167e-03]),
#    'totliveTime_s': 69.15218854333332}],
#  [array([[[-0.40466309, -0.4041748 , -0.4041748 , ..., -0.40380859,
#            -0.40405273, -0.40393066],
#           [-0.69519043, -0.6953125 , -0.6953125 , ..., -0.69592285,
#            -0.69567871, -0.69580078]],
#
#          [[-0.40466309, -0.40405273, -0.4041748 , ..., -0.40393066,
#            -0.40405273, -0.40380859],
#           [-0.69555664, -0.69567871, -0.69567871, ..., -0.69592285,
#            -0.6953125 , -0.69543457]],
#
#          [[-0.40454102, -0.40454102, -0.40405273, ..., -0.40405273,
#            -0.40380859, -0.40405273],
#           [-0.69567871, -0.69580078, -0.69567871, ..., -0.69555664,
#            -0.6953125 , -0.69580078]],
#
#          ...,
#
#          [[-0.40441895, -0.40405273, -0.40454102, ..., -0.40356445,
#            -0.40319824, -0.40344238],
#           [-0.69555664, -0.69567871, -0.69519043, ..., -0.69543457,
#            -0.69580078, -0.69604492]],
#
#          [[-0.40356445, -0.40356445, -0.4041748 , ..., -0.40368652,
#            -0.40405273, -0.40441895],
#           [-0.69567871, -0.69543457, -0.69543457, ..., -0.69555664,
#            -0.69543457, -0.69555664]],
#
#          [[-0.40441895, -0.40454102, -0.40441895, ..., -0.40380859,
#            -0.40380859, -0.40405273],
#           [-0.69580078, -0.69567871, -0.69543457, ..., -0.69592285,
#            -0.69543457, -0.69567871]]]),
#   {'numEvents': 30000,
#    'numSamples': 500,
#    'chMap': array([1, 0, 1]),
#    'numChan': 2,
#    'file': '/data/share/KA0219/UV/1780V_Air_5V_700ns_200806_500_samples_30000_events',
#    'liveTimes_s': array([1.50833333e-06, 2.08906333e-03, 2.35465500e-03, ...,
#           2.54249667e-03, 1.27663500e-03, 2.65555500e-03]),
#    'totliveTime_s': 68.60388527166666}]]

# %%
sumWaves = [wave[0][:,1,:].sum(0)/float(wave[1]['numEvents']) for wave in waveArrs]
sumWaves = [sWave - sWave[:30].sum()/30.0 for sWave in sumWaves]
#sumWaves

# %%
for iw in range(len(sumWaves)):
    mark = '+'
    if 'GdLS' in fWaves[iw]:
        mark = 'x'
    plt.plot(sumWaves[iw],label=fWaves[iw][22:],marker=mark)
plt.legend()
plt.xlabel('Sample (10ns)')
plt.ylabel('V')
#plt.xlim(80,500)

#plt.yscale('log')
plt.savefig('UV_Av.png')

# %%
areas = [au.winQHist(wave,ch=1,init=100,end=250,sub=True,nBase=50,binW=2,doLive=True)['qHist'] for wave in waveArrs]
for iw in range(len(areas)):
    mark = '+'
    if 'GdLS' in fWaves[iw]:
        mark = 'x'
    plt.errorbar(areas[iw][1],areas[iw][0],np.sqrt(areas[iw][2]),label=(waveArrs[iw][1]['file'][22:]),marker=mark)
plt.legend()
plt.xlabel('Q (pC)')
plt.ylabel('dR/dQ [Hz/pC]')
plt.xlim(0,1500)

#plt.yscale('log')
plt.savefig('UV_Q.png')

# %%
fig = au.plotWaves(waveArrs[-1][0][9990:,:],1,1000)
#plt.xticks(np.arange(500,5))

# %%
wave = au.ReadDDC10_BinWave('/data/share/test1_square_200729_500_samples_1000_events')
plt.clf()
au.plotWaves(wave[0],0,3)

# %%
wave = au.ReadDDC10_BinWave('/data/share/test1_200729_500_samples_1000_events')
plt.clf()
au.plotWaves(wave[0],0,4)
