# %%
import numpy as np
import uproot
import matplotlib.pyplot as plt
from scipy import integrate
import AnaUtils as au
import Triggered as tr
import glob
import os

# %%
pmt = "KA0218"
wdir = '/data/share/'+pmt
fWaves = [os.path.splitext(iF)[0] for iF in glob.glob('{}/Gain/*.bin'.format(wdir))]
fWaves.sort()
Gains = np.array([float(iF.split('/')[-1].split('V')[0]) for iF in fWaves])
nGains = len(Gains)
Gains,fWaves,nGains
# Out:
# (array([1600., 1627., 1650., 1675., 1699., 1724., 1751., 1760., 1765.,
#         1770., 1790.]),
#  ['/data/share/KA0218/Gain/1600V_200706_100_samples_30000_events',
#   '/data/share/KA0218/Gain/1627V_200706_100_samples_30000_events',
#   '/data/share/KA0218/Gain/1650V_200706_100_samples_30000_events',
#   '/data/share/KA0218/Gain/1675V_200706_100_samples_30000_events',
#   '/data/share/KA0218/Gain/1699V_200706_100_samples_30000_events',
#   '/data/share/KA0218/Gain/1724V_200706_100_samples_30000_events',
#   '/data/share/KA0218/Gain/1751V_200706_100_samples_30000_events',
#   '/data/share/KA0218/Gain/1760V_200706_100_samples_30000_events',
#   '/data/share/KA0218/Gain/1765V_200706_100_samples_30000_events',
#   '/data/share/KA0218/Gain/1770V_200706_100_samples_30000_events',
#   '/data/share/KA0218/Gain/1790V_200706_100_samples_30000_events'],
#  11)

# %%
QHists = [tr.extRun(iG,30,3,6,qbins=100,plot=False) for iG in fWaves]
QSPE = np.array([0.]*nGains)
QErr = np.array([0.]*nGains)
for iq in range(nGains):
    #plt.plot(QHists[iq][1],QHists[iq][2],marker='x',label=Gains[iq])
    args = QHists[iq][3]
    lst = 'solid'
    try:
        GFit,GErr = tr.fitQ(QHists[iq],[0,12,1,3,1,1])
        QSPE[iq] = GFit[3]
        QErr[iq] = np.sqrt(np.diag(GErr))[3]
    except RuntimeError:
        print("Failed to fit {}V Run".format(Gains[iq]))
        lst = 'dashed'
        QSPE[iq] = np.nan
        QErr[iq] = np.nan
    plt.plot(QHists[iq][1][args],QHists[iq][0][args],marker='+',label=Gains[iq],linestyle=lst)
#plt.yscale('log')
#plt.xlim(-2,10)
plt.legend()
plt.xlabel('Q [pC]')
plt.ylabel('Rate [Hz]')
plt.savefig(pmt+"_GainSPEs.png")
Gains,QSPE,QErr
# Out:
# Failed to fit 1675.0V Run
# Failed to fit 1724.0V Run
# Failed to fit 1751.0V Run
# Failed to fit 1760.0V Run
# (array([1600., 1627., 1650., 1675., 1699., 1724., 1751., 1760., 1765.,
#         1770., 1790.]),
#  array([ 1.74580324,  1.99334687,  2.48295417,         nan, -3.79774258,
#                 nan,         nan,         nan,  2.11605255,  2.14439646,
#          1.9731872 ]),
#  array([1.30591741e-01, 1.59999504e-01, 1.57992383e-01,            nan,
#         1.51751155e+01,            nan,            nan,            nan,
#         9.90002710e-03, 1.01539567e-02, 1.34052525e-02]))

# %%
def fit_gain_curve(v, v0, gamma):
    q = ( v / v0 ) ** gamma
    return q
def fit_gain_line(v,v0,gamma):
    q = gamma*v + v0
    return q
qe = 1.6022e-7

from scipy.optimize import curve_fit
fitQ,fitErr = curve_fit(fit_gain_line,Gains,np.log(QSPE/qe),p0=[1,1e3],sigma=QErr/QSPE,absolute_sigma=True)
fitErr = np.sqrt(np.diag(fitErr))
print((fitQ,fitErr))
from scipy.stats import linregress

slope, intercept, r_value, p_value, std_err = linregress(Gains,np.log(QSPE/qe))
print(slope, intercept, std_err,(np.log(1e7)-intercept)/slope)
# Out:
# /home/lzer/miniconda3/envs/DDC10Ana/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in log
#   # Remove the CWD from sys.path while we load stuff.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-cade80369a60> in <module>
#       8
#       9 from scipy.optimize import curve_fit
# ---> 10 fitQ,fitErr = curve_fit(fit_gain_line,Gains,np.log(QSPE/qe),p0=[1,1e3],sigma=QErr/QSPE,absolute_sigma=True)
#      11 fitErr = np.sqrt(np.diag(fitErr))
#      12 print((fitQ,fitErr))
#
# ~/miniconda3/envs/DDC10Ana/lib/python3.6/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     711     # NaNs can not be handled
#     712     if check_finite:
# --> 713         ydata = np.asarray_chkfinite(ydata, float)
#     714     else:
#     715         ydata = np.asarray(ydata, float)
#
# ~/miniconda3/envs/DDC10Ana/lib/python3.6/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     497     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     498         raise ValueError(
# --> 499             "array must not contain infs or NaNs")
#     500     return a
#     501
#
# ValueError: array must not contain infs or NaNs

# %%
points = fitQ[1] * np.array(Gains) + fitQ[0]
plt.errorbar(Gains,np.exp(points),label='Fit')
plt.errorbar(Gains,QSPE/qe,label='data',yerr = QErr/qe)
plt.plot()
#plt.yscale('log')
#plt.xlim(-2,10)
plt.xlabel('Bias [V]')
plt.ylabel('Gain')
plt.legend()
plt.savefig(pmt+"_GainCurve.png")

# %% [markdown]
# #
