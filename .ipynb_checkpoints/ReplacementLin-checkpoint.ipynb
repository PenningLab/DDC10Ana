# %%
import numpy as np
import uproot
import matplotlib.pyplot as plt
from scipy import integrate
import AnaUtils as au
import Triggered as tr
import glob
import os

# %%
pmt = "KA0123"
wdir = '/data/share/'+pmt
fWaves = [os.path.splitext(iF)[0] for iF in glob.glob('{}/Lin/*.bin'.format(wdir))]
fWaves
# Out:
# ['/data/share/KA0123/Lin/1PE_1283V_50percent_200625_100_samples_20000_events',
#  '/data/share/KA0123/Lin/1PE_1283V_200625_100_samples_100000_events']

# %%
QHists = [tr.extRun(iG,30,10,30,qbins=500) for iG in fWaves]
